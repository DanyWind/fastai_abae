# %%
from fastai.text import *

# %%
k = 14
bs = 32
bptt = 25
m = 5
d = 384

# %%
path = untar_data(URLs.IMDB_SAMPLE)
path
# Out:
# PosixPath('/home/DanyWin/.fastai/data/imdb_sample')

# %%
df = pd.read_csv(path/'texts.csv')
df.head()
# Out:
#       label                                               text  is_valid
# 0  negative  Un-bleeping-believable! Meg Ryan doesn't even ...     False
# 1  positive  This is a extremely well-made film. The acting...     False
# 2  negative  Every once in a long while a movie will come a...     False
# 3  positive  Name just says it all. I watched this movie wi...     False
# 4  negative  This movie succeeds at being one of the most u...     False

# %%
# Language model data
data_lm = TextLMDataBunch.from_csv(path, 'texts.csv',bs=bs,bptt = bptt)
# Classifier model data
# data_clas = TextClasDataBunch.from_csv(path, 'texts.csv', vocab=data_lm.train_ds.vocab, bs=32)

# %%
data_lm.show_batch()
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>idx</th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>brainer in the summer heat , and the cover looked cool . \n \n  xxmaj of course i should 've known better . xxmaj this is</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>. xxmaj only because i like xxmaj judd xxmaj nelson , and he 's the only good part about this sequal . xxbos i saw</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>got them totally confused ) . xxmaj this is n't one of those laugh - a - minute bad movies like " xxmaj the xxmaj</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>rape xxmaj xxunk ( xxmaj carol xxmaj xxunk ) and tells her to take off her clothes . xxmaj dean has turned the radio up</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>. xxmaj she had so much xxunk and yet so much hate at the same time . xxmaj dealing with a ignorant dad did n't</td>
#     </tr>
#   </tbody>
# </table>

# %%
vocab = data_lm.train_ds.vocab

# %%
vocab.itos
# Out:
# ['xxunk',
#  'xxpad',
#  'xxbos',
#  'xxeos',
#  'xxfld',
#  'xxmaj',
#  'xxup',
#  'xxrep',
#  'xxwrep',
#  'the',
#  '.',
#  ',',
#  'and',
#  'a',
#  'of',
#  'to',
#  'is',
#  'it',
#  'in',
#  'i',
#  'that',
#  'this',
#  '"',
#  "'s",
#  '-',
#  '\n \n ',
#  'was',
#  'for',
#  'as',
#  'with',
#  'movie',
#  'but',
#  'film',
#  'you',
#  ')',
#  'on',
#  '(',
#  "n't",
#  'are',
#  'not',
#  'his',
#  'he',
#  'have',
#  'be',
#  'they',
#  'one',
#  'at',
#  'all',
#  'by',
#  'like',
#  'an',
#  'from',
#  'so',
#  'who',
#  '!',
#  'there',
#  'about',
#  'if',
#  'or',
#  'just',
#  'out',
#  "'",
#  'some',
#  'do',
#  'her',
#  'what',
#  'has',
#  '?',
#  'more',
#  'good',
#  'very',
#  'up',
#  'when',
#  'no',
#  'would',
#  'really',
#  'she',
#  'were',
#  'even',
#  'time',
#  'their',
#  'only',
#  'had',
#  'my',
#  'story',
#  'which',
#  'can',
#  'see',
#  'did',
#  'well',
#  'into',
#  'we',
#  'me',
#  ':',
#  '...',
#  'will',
#  'bad',
#  'get',
#  'also',
#  'much',
#  'people',
#  'than',
#  'does',
#  'other',
#  'first',
#  'been',
#  'could',
#  'because',
#  'great',
#  'most',
#  'two',
#  'made',
#  'its',
#  'then',
#  'make',
#  '/',
#  'any',
#  'way',
#  'them',
#  'him',
#  'after',
#  'how',
#  'too',
#  'acting',
#  'watch',
#  'think',
#  'never',
#  ';',
#  'plot',
#  'many',
#  'movies',
#  'films',
#  'where',
#  'little',
#  'seen',
#  'being',
#  'man',
#  'life',
#  'character',
#  'here',
#  'characters',
#  'better',
#  'over',
#  'your',
#  'know',
#  'end',
#  'should',
#  'while',
#  'show',
#  'best',
#  'off',
#  'scenes',
#  'love',
#  'through',
#  'go',
#  'ever',
#  'scene',
#  'something',
#  'these',
#  'say',
#  'why',
#  'still',
#  '--',
#  'such',
#  'those',
#  'watching',
#  '10',
#  'back',
#  'actually',
#  'years',
#  'before',
#  'though',
#  'between',
#  'actors',
#  'pretty',
#  'quite',
#  "'m",
#  "'ve",
#  'old',
#  'new',
#  'nothing',
#  'real',
#  'funny',
#  'going',
#  'thing',
#  'find',
#  'same',
#  'around',
#  "'re",
#  'another',
#  'few',
#  'makes',
#  'now',
#  'part',
#  'want',
#  '&',
#  'work',
#  'director',
#  'action',
#  'world',
#  'fact',
#  'lot',
#  'look',
#  'down',
#  'again',
#  'seems',
#  'us',
#  'got',
#  'cast',
#  'ca',
#  'series',
#  'big',
#  '*',
#  'almost',
#  'young',
#  'bit',
#  'things',
#  'thought',
#  'horror',
#  'enough',
#  'every',
#  'both',
#  'without',
#  'family',
#  'point',
#  'whole',
#  'own',
#  'times',
#  'probably',
#  'must',
#  'take',
#  'however',
#  'might',
#  'may',
#  'gets',
#  "'ll",
#  'give',
#  'day',
#  'least',
#  'minutes',
#  'original',
#  'interesting',
#  'feel',
#  'kind',
#  'each',
#  'anything',
#  'saw',
#  'place',
#  'right',
#  'come',
#  'looks',
#  'tv',
#  'fun',
#  'true',
#  'last',
#  'since',
#  'making',
#  'away',
#  'comedy',
#  'script',
#  'goes',
#  'role',
#  'hard',
#  'done',
#  'course',
#  'trying',
#  'girl',
#  'found',
#  'effects',
#  'long',
#  'book',
#  'together',
#  'someone',
#  'our',
#  'women',
#  'shows',
#  'having',
#  'simply',
#  'comes',
#  'set',
#  'far',
#  'always',
#  'audience',
#  'looking',
#  'believe',
#  'screen',
#  'star',
#  'american',
#  'sense',
#  'shot',
#  'left',
#  'rest',
#  "'d",
#  'sure',
#  'worst',
#  'three',
#  'performance',
#  'worth',
#  '\x96',
#  'guy',
#  'actor',
#  'woman',
#  'men',
#  'played',
#  'later',
#  'read',
#  'yet',
#  'special',
#  'anyone',
#  'takes',
#  'once',
#  'wife',
#  '4',
#  'music',
#  'black',
#  'put',
#  'instead',
#  'maybe',
#  'said',
#  'friends',
#  'year',
#  'although',
#  'watched',
#  'especially',
#  'rather',
#  'low',
#  'production',
#  'war',
#  'either',
#  '2',
#  'am',
#  'second',
#  'mind',
#  'beautiful',
#  'let',
#  'main',
#  'everyone',
#  'perhaps',
#  'ending',
#  'dvd',
#  'john',
#  'half',
#  'budget',
#  'plays',
#  'next',
#  'different',
#  'top',
#  'nice',
#  'seem',
#  'kids',
#  'episode',
#  'video',
#  'others',
#  'need',
#  'reason',
#  'high',
#  'version',
#  'idea',
#  'start',
#  'during',
#  '1',
#  'robert',
#  'try',
#  'wrong',
#  'came',
#  'case',
#  'sex',
#  'name',
#  'couple',
#  'getting',
#  'less',
#  'piece',
#  'kill',
#  'already',
#  'play',
#  'night',
#  'house',
#  'liked',
#  'terrible',
#  'keep',
#  'poor',
#  'excellent',
#  'full',
#  'performances',
#  'along',
#  'help',
#  'early',
#  'job',
#  'everything',
#  'use',
#  'else',
#  'lost',
#  'boring',
#  'entire',
#  'himself',
#  'supposed',
#  'often',
#  'used',
#  'sound',
#  'tell',
#  'death',
#  'father',
#  'completely',
#  'hollywood',
#  'style',
#  'person',
#  'money',
#  'throughout',
#  'fan',
#  'girls',
#  'cinema',
#  'killer',
#  'classic',
#  'lines',
#  'seemed',
#  'dialogue',
#  'stars',
#  'given',
#  'live',
#  'oh',
#  'truly',
#  'turn',
#  'moments',
#  'camera',
#  'despite',
#  'written',
#  'enjoy',
#  'boy',
#  'felt',
#  'waste',
#  'home',
#  'stupid',
#  'yes',
#  'until',
#  '3',
#  'wo',
#  'decent',
#  'days',
#  'child',
#  'title',
#  'overall',
#  '5',
#  'awful',
#  'face',
#  'drama',
#  'absolutely',
#  'remember',
#  'except',
#  'definitely',
#  'close',
#  'children',
#  'called',
#  'friend',
#  'unfortunately',
#  'blood',
#  'picture',
#  'school',
#  'town',
#  'small',
#  'game',
#  'doing',
#  'history',
#  'says',
#  'car',
#  'problem',
#  'become',
#  'five',
#  'english',
#  'short',
#  'quality',
#  'writing',
#  'itself',
#  'hope',
#  'worse',
#  'run',
#  'sort',
#  'hand',
#  'seeing',
#  'attempt',
#  'turns',
#  'head',
#  'word',
#  'went',
#  'late',
#  'recommend',
#  'playing',
#  'dead',
#  'documentary',
#  'past',
#  'entertaining',
#  'anyway',
#  'under',
#  'gore',
#  '..',
#  'fine',
#  'leave',
#  'able',
#  'mean',
#  'sometimes',
#  'parts',
#  'wonderful',
#  'eyes',
#  'white',
#  'city',
#  'thinking',
#  'beginning',
#  'human',
#  'wanted',
#  'flick',
#  'heard',
#  'certainly',
#  'lives',
#  'killed',
#  'told',
#  'against',
#  'ridiculous',
#  'side',
#  'care',
#  'gives',
#  'based',
#  'violence',
#  'genre',
#  'hero',
#  'humor',
#  'tries',
#  'lead',
#  'dull',
#  'group',
#  'order',
#  'final',
#  'modern',
#  'exactly',
#  'themselves',
#  'michael',
#  'finds',
#  'lady',
#  'lack',
#  'eye',
#  'several',
#  'hit',
#  'nearly',
#  'self',
#  'highly',
#  'shown',
#  'opinion',
#  'stuff',
#  'line',
#  'direction',
#  'heart',
#  'cheap',
#  'non',
#  'behind',
#  'level',
#  'happen',
#  'viewer',
#  'light',
#  'guess',
#  'guys',
#  'expect',
#  'alone',
#  'totally',
#  'voice',
#  'knows',
#  'etc',
#  'king',
#  'obviously',
#  'red',
#  'loved',
#  'episodes',
#  'god',
#  'crap',
#  'cinematography',
#  'paul',
#  'hour',
#  'dark',
#  'wants',
#  'tells',
#  'oscar',
#  'serious',
#  'novel',
#  'please',
#  'yourself',
#  'laugh',
#  'son',
#  'wonder',
#  'happens',
#  'roles',
#  'local',
#  'somewhat',
#  'follow',
#  'feeling',
#  'relationship',
#  'mother',
#  'finally',
#  'works',
#  'events',
#  'victor',
#  'interest',
#  'general',
#  'george',
#  'four',
#  'kid',
#  'directed',
#  'upon',
#  'example',
#  'ben',
#  'brilliant',
#  'space',
#  'horrible',
#  'slow',
#  'score',
#  'brother',
#  're',
#  'perfect',
#  'starts',
#  'problems',
#  'usually',
#  'sister',
#  'country',
#  'matter',
#  'bunch',
#  'type',
#  'taken',
#  'mr.',
#  'seriously',
#  'release',
#  'review',
#  'de',
#  'known',
#  'cut',
#  'james',
#  'talking',
#  'involved',
#  'saying',
#  'ago',
#  'ten',
#  'boys',
#  'steve',
#  'knew',
#  'obvious',
#  'tale',
#  'similar',
#  'moment',
#  'daughter',
#  '8',
#  'enjoyed',
#  'actress',
#  'working',
#  'gone',
#  'save',
#  'lake',
#  'particularly',
#  'possible',
#  'body',
#  'monster',
#  'female',
#  'sexual',
#  'evil',
#  'major',
#  'mention',
#  'age',
#  'art',
#  'took',
#  'fans',
#  'shots',
#  'myself',
#  'mostly',
#  'fight',
#  'team',
#  'became',
#  'cover',
#  'including',
#  '7',
#  'huge',
#  'stories',
#  'sets',
#  'basically',
#  'turned',
#  'secret',
#  'across',
#  'romance',
#  'none',
#  'stop',
#  'happened',
#  'earth',
#  'leads',
#  'soundtrack',
#  'released',
#  'york',
#  'rating',
#  'gave',
#  'using',
#  'clearly',
#  'soon',
#  'apparently',
#  'ways',
#  'disappointed',
#  'ends',
#  'laughs',
#  'murder',
#  'figure',
#  'luke',
#  'extremely',
#  'particular',
#  'plenty',
#  'police',
#  'zombie',
#  'woods',
#  'favorite',
#  'note',
#  'western',
#  'comic',
#  'supporting',
#  'above',
#  'number',
#  'japanese',
#  'parents',
#  'effort',
#  'german',
#  'silly',
#  'doubt',
#  'strong',
#  'words',
#  'due',
#  'writer',
#  'today',
#  'editing',
#  'british',
#  'falls',
#  'ok',
#  'difficult',
#  'ones',
#  'coming',
#  'named',
#  'add',
#  'bring',
#  'cool',
#  'appear',
#  'future',
#  'sad',
#  'typical',
#  'room',
#  'easy',
#  'near',
#  'becomes',
#  'complete',
#  'living',
#  '6',
#  'feature',
#  'needs',
#  'enjoyable',
#  'twist',
#  'dialog',
#  'important',
#  'list',
#  'wish',
#  'giving',
#  'change',
#  'simple',
#  'forget',
#  'filmed',
#  'romantic',
#  'french',
#  'clear',
#  'happy',
#  'devil',
#  'footage',
#  'business',
#  'chance',
#  'portrayed',
#  'large',
#  'theme',
#  'nature',
#  'form',
#  'running',
#  'office',
#  'attention',
#  'subject',
#  'hardly',
#  'imagine',
#  'chase',
#  'understand',
#  'sit',
#  'begin',
#  'message',
#  'create',
#  'appears',
#  'surprised',
#  'annoying',
#  'jokes',
#  'audiences',
#  'b',
#  'towards',
#  'spent',
#  'call',
#  'fantastic',
#  'view',
#  'career',
#  'showing',
#  'opening',
#  'whatever',
#  'weak',
#  'thriller',
#  'amazing',
#  'entertainment',
#  'forced',
#  'whether',
#  'features',
#  'power',
#  'army',
#  'killing',
#  'beyond',
#  'cheesy',
#  'feels',
#  'material',
#  'usual',
#  'west',
#  'started',
#  'agree',
#  'easily',
#  'caught',
#  '20',
#  'mess',
#  'focus',
#  'hilarious',
#  'porn',
#  'agent',
#  'cgi',
#  'tension',
#  'setting',
#  'earlier',
#  'experience',
#  '80',
#  'society',
#  'husband',
#  'remake',
#  'hours',
#  'within',
#  'jimmy',
#  'rent',
#  'recently',
#  'box',
#  'strange',
#  'herself',
#  'tom',
#  'baby',
#  'blob',
#  'stage',
#  'dramatic',
#  'average',
#  'deal',
#  'possibly',
#  'indeed',
#  'whose',
#  'language',
#  'screenplay',
#  'davis',
#  'talk',
#  'miss',
#  'talent',
#  'predictable',
#  'third',
#  'joe',
#  'science',
#  'realistic',
#  'tried',
#  'comments',
#  'cartoon',
#  'la',
#  'south',
#  'bill',
#  'leading',
#  'scary',
#  'hear',
#  'certain',
#  'truth',
#  'rich',
#  'normal',
#  'crew',
#  'sequences',
#  'free',
#  'unless',
#  'taking',
#  'okay',
#  'total',
#  'apart',
#  'act',
#  'slasher',
#  'suspense',
#  'deserves',
#  'weird',
#  'homer',
#  'stand',
#  'attempts',
#  'david',
#  'reality',
#  'single',
#  'lee',
#  'break',
#  'jack',
#  'former',
#  'die',
#  'door',
#  'somehow',
#  'present',
#  'incredibly',
#  'greatest',
#  'deep',
#  'unique',
#  'kept',
#  'died',
#  'shame',
#  'question',
#  'stick',
#  'runs',
#  'keeps',
#  'viewing',
#  'company',
#  'laughing',
#  'crime',
#  'fire',
#  'kills',
#  'public',
#  'avoid',
#  'christmas',
#  'state',
#  'looked',
#  'points',
#  'indian',
#  'learn',
#  'open',
#  'meets',
#  'scott',
#  'eventually',
#  'meaning',
#  'stay',
#  'directors',
#  'water',
#  'middle',
#  'interested',
#  'hell',
#  'surprise',
#  'social',
#  'mentioned',
#  'allen',
#  'al',
#  'straight',
#  'period',
#  'move',
#  'values',
#  'dance',
#  'missed',
#  'believable',
#  'dream',
#  'realize',
#  'means',
#  'dad',
#  'richard',
#  'helps',
#  'brothers',
#  'america',
#  'gun',
#  'vargas',
#  'street',
#  'jane',
#  'actual',
#  'rock',
#  'missing',
#  'sitting',
#  'outside',
#  'involving',
#  'decided',
#  'suddenly',
#  'government',
#  'mystery',
#  'sadly',
#  'explain',
#  'grade',
#  'comment',
#  'rated',
#  'era',
#  'emotional',
#  'acted',
#  'fairly',
#  'moving',
#  'convincing',
#  'male',
#  'dressed',
#  'violent',
#  'meant',
#  'beauty',
#  'rose',
#  'brooks',
#  'sorry',
#  'expecting',
#  'adaptation',
#  'alive',
#  'musical',
#  'narrative',
#  'surprisingly',
#  ...]

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
tokens = nlp(" ".join(vocab.itos))

# %%
output = []

for token in tokens:
    output.append({"text":token.text,"has_vector":token.has_vector,"vector":token.vector})

# %%
df = pd.DataFrame(output)
# Normalization
df.vector = df.vector.apply(lambda x : x / np.linalg.norm(x))

# %%
vectors = df.vector.values

# %%
vectors = np.stack(vectors)

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=k, random_state=0).fit(vectors)

# %%
aspects = kmeans.cluster_centers_.T

# %%
x,y = data_lm.one_batch()

# %%
class SentenceEmbedder(nn.Module):
    def __init__(self,word_vectors,embedding_dim,freeze=True):
        super(SentenceEmbedder,self).__init__()
        
        # We initialize the word embeddings
        self.word_vectors = nn.Embedding(*word_vectors.shape)
        self.word_vectors.weight.data = torch.tensor(word_vectors)
        
        if freeze:
            self.word_vectors.weight.requires_grad = False
        
        self.M = nn.Linear(embedding_dim,embedding_dim,bias=False)
        
    def forward(self,x):
        # First we convert each word index to word embeddings
        x = self.word_vectors(x)
        
        # Then we pass it to the bilinear product
        y = x.mean(dim = 1)
        d = self.M(y)
        
        # We compute for each word of a sentence its product with My
        d = torch.einsum("ijk,ik -> ij",x,d)
        
        # We softmax the output
        a = F.softmax(d,dim = 1)
        
        # Finally we multiply and sum
        z = (a[:,:,None] * x).sum(dim = 1)
        
        # We store the z to later compute the loss
        self.z = z
        self.n = y
        
        return z
    
class SentenceAutoEncoder(nn.Module):
    def __init__(self,aspect_vectors,embedding_dim,n_aspect):
        super(SentenceAutoEncoder,self).__init__()
        
        self.W = nn.Linear(embedding_dim,n_aspect)
        
        self.T = nn.Linear(n_aspect,embedding_dim,bias=False)
        self.T.weight.data = torch.tensor(aspect_vectors)
        
    def forward(self,z):
        # First we project our sentence embedding to its aspects
        p = self.W(z)
        p = F.softmax(p,dim = 1)
        
        # Finally we reconstruct the sentence embedding from its aspects
        r = self.T(p)
        
        return r
    
    def predict(self,z):
        
        # First we project our sentence embedding to its aspects
        p = self.W(z)
        p = F.softmax(p,dim = 1)
        
        return p

# %%
class ABAE(nn.Module):
    def __init__(self,word_vectors,aspect_vectors,embedding_dim,n_aspect):
        super(ABAE,self).__init__()
        
        self.embedder = SentenceEmbedder(word_vectors=word_vectors,embedding_dim=embedding_dim)
        self.autoencoder = SentenceAutoEncoder(aspect_vectors=aspect_vectors,embedding_dim=embedding_dim,
                                              n_aspect=n_aspect)
        
    def forward(self,x):
        z = self.embedder(x)
        r = self.autoencoder(z)
        
        return r  
    
    def predict(self,x):
        z = self.embedder(x)
        p = self.autoencoder.predict(z)
        
        return p

# %%
model = ABAE(word_vectors=vectors,aspect_vectors=aspects,embedding_dim=d,n_aspect=k)

# %%
def loss_func(r,y,abae,alpha=1,m=5):
    z = abae.embedder.z.detach()
    n = abae.embedder.n.detach()
    
    bs = z.shape[0]
    
    # We compute the Hinge loss
    positive = torch.einsum("ij,ij -> i",r,z)
    
    # We first create batches of negative samples
    negative_idx = []
    for i in range(bs):
        choice = np.delete(np.arange(bs),i)
        choice = np.random.choice(choice,m,replace=False)
        negative_idx.append(choice)

    negative_idx = np.stack(negative_idx)
    negative_idx = torch.tensor(negative_idx)
    
    # We broadcast first our batch then take the negative samples
    n = n.expand(bs,-1,-1)
    
    output = []
    for i in range(bs):
        v = n[i,negative_idx[i]]
        output.append(v)
    negative = torch.stack(output)
    
    # We compute the inner products
    negative = torch.einsum("ijk,ik -> ij",negative,r)
    
    # We compute the final loss
    J = (F.relu(1 + negative - positive[:,None])).sum(dim = 1).mean()
    
    # We compute the regularization loss
    T = abae.autoencoder.T.weight
    gram = torch.matmul(torch.t(T),T)
    
    k = gram.shape[0]
    I = torch.diag(torch.ones(k)).cuda()
    U = ((gram - I) ** 2).sum()
    
    loss = J + alpha * U
    
    return loss

# %%
loss = partial(loss_func,abae=model)

# %%
learn = Learner(data_lm,model,loss_func=loss)

learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(4,1e-2)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.971953</td>
#       <td>0.910828</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.801444</td>
#       <td>0.863289</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.794914</td>
#       <td>0.866373</td>
#       <td>00:03</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.787732</td>
#       <td>0.855077</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %%
np.stack(df.vector.values)
# Out:
# array([[-0.054987,  0.127728,  0.013168, -0.007802, ...,  0.005744, -0.022555,  0.014027,  0.013279],
#        [ 0.038733, -0.078195,  0.01759 ,  0.037737, ..., -0.026509, -0.007611,  0.007216,  0.023885],
#        [-0.058198,  0.110166,  0.052109,  0.031378, ...,  0.005653, -0.018039,  0.025473,  0.01192 ],
#        [ 0.196455,  0.046681,  0.060986, -0.041228, ..., -0.020235, -0.017996,  0.036498, -0.004269],
#        ...,
#        [ 0.00463 ,  0.065248,  0.028484,  0.153591, ..., -0.005625, -0.002415,  0.023879,  0.0099  ],
#        [ 0.01218 ,  0.068062,  0.017075,  0.163996, ..., -0.005602, -0.00243 ,  0.023418,  0.009989],
#        [ 0.042761,  0.046332,  0.037616,  0.152793, ..., -0.005839, -0.003081,  0.019471,  0.010766],
#        [ 0.059797,  0.082514,  0.151663,  0.179642, ..., -0.009442, -0.016685,  0.022625,  0.007916]], dtype=float32)

# %%
model.embedder.word_vectors.weight.data
# Out:
# tensor([[-0.0550,  0.1277,  0.0132,  ..., -0.0226,  0.0140,  0.0133],
#         [ 0.0387, -0.0782,  0.0176,  ..., -0.0076,  0.0072,  0.0239],
#         [-0.0582,  0.1102,  0.0521,  ..., -0.0180,  0.0255,  0.0119],
#         ...,
#         [ 0.0122,  0.0681,  0.0171,  ..., -0.0024,  0.0234,  0.0100],
#         [ 0.0428,  0.0463,  0.0376,  ..., -0.0031,  0.0195,  0.0108],
#         [ 0.0598,  0.0825,  0.1517,  ..., -0.0167,  0.0226,  0.0079]],
#        device='cuda:0')

# %%
p = model.predict(x.cuda())

# %%
p
# Out:
# tensor([[9.2665e-06, 5.7443e-07, 5.6032e-07, 1.4995e-06, 5.2032e-07, 7.1119e-07,
#          2.1756e-06, 3.6946e-07, 1.6075e-06, 6.6856e-07, 5.8613e-07, 5.3867e-07,
#          9.9998e-01, 5.6557e-07],
#         [9.3314e-06, 5.8212e-07, 5.6908e-07, 1.5205e-06, 5.2752e-07, 7.2114e-07,
#          2.2041e-06, 3.7463e-07, 1.6344e-06, 6.7912e-07, 5.9439e-07, 5.4548e-07,
#          9.9998e-01, 5.7338e-07],
#         [9.2183e-06, 5.6969e-07, 5.5521e-07, 1.4863e-06, 5.1617e-07, 7.0519e-07,
#          2.1576e-06, 3.6634e-07, 1.5910e-06, 6.6221e-07, 5.8110e-07, 5.3422e-07,
#          9.9998e-01, 5.6098e-07],
#         [9.2026e-06, 5.6810e-07, 5.5345e-07, 1.4818e-06, 5.1476e-07, 7.0318e-07,
#          2.1513e-06, 3.6526e-07, 1.5850e-06, 6.6007e-07, 5.7939e-07, 5.3267e-07,
#          9.9998e-01, 5.5940e-07],
#         [9.1904e-06, 5.6703e-07, 5.5234e-07, 1.4789e-06, 5.1381e-07, 7.0184e-07,
#          2.1474e-06, 3.6456e-07, 1.5815e-06, 6.5858e-07, 5.7837e-07, 5.3170e-07,
#          9.9998e-01, 5.5840e-07],
#         [9.1904e-06, 5.6739e-07, 5.5282e-07, 1.4799e-06, 5.1412e-07, 7.0233e-07,
#          2.1488e-06, 3.6477e-07, 1.5832e-06, 6.5919e-07, 5.7871e-07, 5.3199e-07,
#          9.9998e-01, 5.5872e-07],
#         [9.1942e-06, 5.6757e-07, 5.5294e-07, 1.4803e-06, 5.1428e-07, 7.0252e-07,
#          2.1493e-06, 3.6488e-07, 1.5835e-06, 6.5935e-07, 5.7888e-07, 5.3218e-07,
#          9.9998e-01, 5.5891e-07],
#         [9.4732e-06, 6.0222e-07, 5.9142e-07, 1.5780e-06, 5.4376e-07, 7.4725e-07,
#          2.2813e-06, 3.8660e-07, 1.7064e-06, 7.0685e-07, 6.1629e-07, 5.6353e-07,
#          9.9998e-01, 5.9126e-07],
#         [9.1781e-06, 5.6591e-07, 5.5118e-07, 1.4760e-06, 5.1282e-07, 7.0043e-07,
#          2.1433e-06, 3.6383e-07, 1.5783e-06, 6.5726e-07, 5.7713e-07, 5.3065e-07,
#          9.9998e-01, 5.5731e-07],
#         [9.2729e-06, 5.7648e-07, 5.6252e-07, 1.5051e-06, 5.2201e-07, 7.1400e-07,
#          2.1826e-06, 3.7053e-07, 1.6132e-06, 6.7141e-07, 5.8806e-07, 5.4020e-07,
#          9.9998e-01, 5.6735e-07],
#         [9.2371e-06, 5.7160e-07, 5.5729e-07, 1.4917e-06, 5.1782e-07, 7.0762e-07,
#          2.1649e-06, 3.6759e-07, 1.5978e-06, 6.6483e-07, 5.8313e-07, 5.3600e-07,
#          9.9998e-01, 5.6282e-07],
#         [9.3650e-06, 5.8330e-07, 5.6918e-07, 1.5225e-06, 5.2780e-07, 7.2223e-07,
#          2.2056e-06, 3.7506e-07, 1.6322e-06, 6.8026e-07, 5.9533e-07, 5.4653e-07,
#          9.9998e-01, 5.7363e-07],
#         [9.4990e-06, 5.9851e-07, 5.8604e-07, 1.5610e-06, 5.4198e-07, 7.4094e-07,
#          2.2579e-06, 3.8502e-07, 1.6805e-06, 6.9952e-07, 6.1074e-07, 5.6019e-07,
#          9.9998e-01, 5.8831e-07],
#         [9.3224e-06, 5.8299e-07, 5.7053e-07, 1.5239e-06, 5.2777e-07, 7.2286e-07,
#          2.2074e-06, 3.7503e-07, 1.6403e-06, 6.8115e-07, 5.9610e-07, 5.4606e-07,
#          9.9998e-01, 5.7335e-07],
#         [9.4240e-06, 5.9228e-07, 5.7995e-07, 1.5475e-06, 5.3577e-07, 7.3422e-07,
#          2.2390e-06, 3.8079e-07, 1.6657e-06, 6.9262e-07, 6.0543e-07, 5.5464e-07,
#          9.9998e-01, 5.8224e-07],
#         [9.1959e-06, 5.6761e-07, 5.5293e-07, 1.4806e-06, 5.1432e-07, 7.0259e-07,
#          2.1495e-06, 3.6491e-07, 1.5836e-06, 6.5948e-07, 5.7892e-07, 5.3221e-07,
#          9.9998e-01, 5.5895e-07],
#         [9.2228e-06, 5.7021e-07, 5.5569e-07, 1.4872e-06, 5.1666e-07, 7.0584e-07,
#          2.1585e-06, 3.6660e-07, 1.5914e-06, 6.6264e-07, 5.8156e-07, 5.3451e-07,
#          9.9998e-01, 5.6145e-07],
#         [9.1941e-06, 5.6784e-07, 5.5330e-07, 1.4812e-06, 5.1447e-07, 7.0290e-07,
#          2.1503e-06, 3.6507e-07, 1.5848e-06, 6.5981e-07, 5.7918e-07, 5.3239e-07,
#          9.9998e-01, 5.5913e-07],
#         [9.2469e-06, 5.7334e-07, 5.5924e-07, 1.4945e-06, 5.1957e-07, 7.0998e-07,
#          2.1693e-06, 3.6874e-07, 1.6025e-06, 6.6646e-07, 5.8482e-07, 5.3740e-07,
#          9.9998e-01, 5.6472e-07],
#         [8.5318e-05, 1.7388e-05, 1.9907e-05, 4.6006e-05, 1.3475e-05, 2.1266e-05,
#          5.7336e-05, 1.1315e-05, 6.7318e-05, 2.9802e-05, 1.9759e-05, 1.5907e-05,
#          9.9958e-01, 1.5298e-05],
#         [9.1778e-06, 5.6591e-07, 5.5120e-07, 1.4761e-06, 5.1283e-07, 7.0043e-07,
#          2.1434e-06, 3.6384e-07, 1.5784e-06, 6.5728e-07, 5.7712e-07, 5.3065e-07,
#          9.9998e-01, 5.5731e-07],
#         [9.1743e-06, 5.6560e-07, 5.5088e-07, 1.4753e-06, 5.1254e-07, 7.0005e-07,
#          2.1423e-06, 3.6363e-07, 1.5775e-06, 6.5690e-07, 5.7682e-07, 5.3037e-07,
#          9.9998e-01, 5.5701e-07],
#         [9.3709e-06, 5.8526e-07, 5.7162e-07, 1.5287e-06, 5.2982e-07, 7.2497e-07,
#          2.2152e-06, 3.7628e-07, 1.6414e-06, 6.8260e-07, 5.9747e-07, 5.4832e-07,
#          9.9998e-01, 5.7569e-07],
#         [9.1777e-06, 5.6587e-07, 5.5114e-07, 1.4759e-06, 5.1279e-07, 7.0037e-07,
#          2.1432e-06, 3.6381e-07, 1.5782e-06, 6.5718e-07, 5.7708e-07, 5.3062e-07,
#          9.9998e-01, 5.5726e-07],
#         [9.2168e-06, 5.6990e-07, 5.5545e-07, 1.4872e-06, 5.1627e-07, 7.0549e-07,
#          2.1584e-06, 3.6642e-07, 1.5914e-06, 6.6269e-07, 5.8141e-07, 5.3430e-07,
#          9.9998e-01, 5.6105e-07],
#         [9.7132e-06, 6.2578e-07, 6.1589e-07, 1.6388e-06, 5.6524e-07, 7.7974e-07,
#          2.3680e-06, 4.0265e-07, 1.7714e-06, 7.3469e-07, 6.4106e-07, 5.8520e-07,
#          9.9998e-01, 6.1402e-07],
#         [9.2806e-06, 5.7496e-07, 5.6035e-07, 1.4994e-06, 5.2080e-07, 7.1164e-07,
#          2.1753e-06, 3.6966e-07, 1.6048e-06, 6.6857e-07, 5.8661e-07, 5.3895e-07,
#          9.9998e-01, 5.6585e-07],
#         [9.2817e-06, 5.8545e-07, 5.7395e-07, 1.5381e-06, 5.2911e-07, 7.2668e-07,
#          2.2219e-06, 3.7622e-07, 1.6562e-06, 6.8900e-07, 5.9897e-07, 5.4788e-07,
#          9.9998e-01, 5.7481e-07],
#         [9.2733e-06, 5.7826e-07, 5.6546e-07, 1.5106e-06, 5.2353e-07, 7.1664e-07,
#          2.1899e-06, 3.7182e-07, 1.6241e-06, 6.7457e-07, 5.9072e-07, 5.4185e-07,
#          9.9998e-01, 5.6894e-07],
#         [9.1782e-06, 5.6604e-07, 5.5135e-07, 1.4766e-06, 5.1292e-07, 7.0061e-07,
#          2.1439e-06, 3.6391e-07, 1.5790e-06, 6.5753e-07, 5.7728e-07, 5.3075e-07,
#          9.9998e-01, 5.5741e-07],
#         [4.7570e-05, 8.3594e-06, 1.0071e-05, 2.1689e-05, 6.7693e-06, 1.0724e-05,
#          2.6970e-05, 5.1982e-06, 3.0549e-05, 1.2513e-05, 9.2195e-06, 7.3050e-06,
#          9.9980e-01, 7.1327e-06],
#         [9.3346e-06, 5.8407e-07, 5.7102e-07, 1.5279e-06, 5.2787e-07, 7.2379e-07,
#          2.2111e-06, 3.7539e-07, 1.6443e-06, 6.8355e-07, 5.9671e-07, 5.4711e-07,
#          9.9998e-01, 5.7415e-07]], device='cuda:0', grad_fn=<SoftmaxBackward>)

# %%
p.argmin(dim = 1)
# Out:
# tensor([7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7, 7,
#         7, 7, 7, 7, 7, 7, 7, 7], device='cuda:0')

# %%
x_str = x.numpy()

# %%
output = []
for i in range(len(x_str)):
    s = x_str[i]
    sentence = ""
    for j in range(len(s)):
        word = vocab.itos[s[j]]
        sentence += " " + word
    output.append(sentence)

# %%
output
# Out:
# [" a really , really bad movie . xxmaj and it gets xxunk when the makers know it 's bad , and try cover it up",
#  ' this movie a few days ago ... what the hell was that ? \n \n  i like movies with xxmaj brian xxunk , they are funny',
#  ' xxunk " , it \'s just a really , really bad movie . \n \n  xxbos xxmaj jungle xxmaj fever is too highly stylized , stereotyped',
#  " to drown out the noise of what he 's about to do . xxmaj the preacher on the radio needs to go back and read",
#  ' really help her much . xxmaj even though he loved her he was really hateful . xxmaj her mother died when she was younger and',
#  ' in the form of furious xxunk played by xxmaj xxunk xxmaj xxunk xxunk . xxmaj carol dolls herself up as a girl of easy virtue',
#  ' were so ridiculously unbelievable that i was happy he chose to leave out some of the most important parts of the novel . xxmaj the',
#  ' full of no - name actors and actresses with little valuable plot . \n \n  xxmaj anyway , this strange game goes on and our "',
#  ' him as a hit - man in the xxmaj xxunk xxmaj tessari thriller " xxmaj big xxmaj guns " after they accidentally murder his wife',
#  ' itself , and if well done , will satisfy most xxunk . xxmaj jane xxmaj fonda was unable to hide her xxunk enough to make',
#  ' noise that sounds like a xxunk xxunk . xxmaj after the movie , i heard several people exiting the theatre making the sound and laughing',
#  " and well - developed , i was disappointed to find that they did n't change very much throughout the show . xxmaj their relationship grew",
#  ' man and xxmaj nature and an uneven musical score with xxunk songs at the most inappropriate moments . i guess the word " xxunk "',
#  ' the movie did look good , just not the xxunk explosions . \n \n  xxmaj some of the sound effects are very cheesy , as if',
#  ' than a few good scenes , this character seems pretty much wasted . \n \n  xxmaj while i really enjoyed the insight this movie gave ,',
#  ' a huge mask ( as is always done when the xxmaj balanchine production is performed onstage ) , xxmaj culkin is actually made up as',
#  ' feature film ! xxmaj it certainly has no legs , xxunk as except for its xxunk ultimate resolution forced upon it by history , xxmaj',
#  ' xxmaj xxunk , with a xxunk complex story and acting more wooden than that found in a xxmaj john xxmaj agar film . xxmaj shi',
#  " dahmer story , of which i know very little . xxmaj people here seem to think that the movie did n't have to cover the",
#  ' out here ) ... but all of those games , as well as the rest of the genre , owe their existence to this one',
#  " xxmaj daniel xxmaj day xxmaj lewis , the actor drawing xxmaj scorsese 's camera xxunk toward him like a moth to a xxunk . \n \n ",
#  ' the main action sequences . xxmaj nothing is too outlandish for " xxmaj the xxmaj crater xxmaj lake xxmaj monster " . xxmaj it explains',
#  ' . xxmaj again , it is not a great film , and it is probably best watched on a rainy day when you need some',
#  " and insipid scripts i 'd ever read would be a bold understatement . xxmaj yet i never told him this . xxmaj why ? xxmaj",
#  " xxmaj august 's stunning portion was mostly overlooked ; he did n't receive the xxmaj oscar nomination he rightly deserved . \n \n  xxmaj this is",
#  ' ) . \n \n  xxmaj incidentally , xxup fanfan xxup la xxup tulipe has quite a bit in common with the xxunk - mentioned xxup cartouche',
#  ' xxmaj carnosaurs " are really ridiculous . a scientist tells the soldiers that they move incredibly fast , yet when you see them run ,',
#  " untergang this is a huge disappointment . xxmaj there 's no connection between different scenes , and the acting is so incredibly poor i could",
#  ' xxmaj luke was portrayed was absolutely ridiculous . xxmaj he was supposed to be a xxunk playboy who was someday to inherit the house (',
#  ' xxmaj candy and the teenage kid also diluted the general quality of the show , and the death of xxmaj hoss ( xxmaj dan xxmaj',
#  ' film but when you know how many shooting days it took ( xxunk ) and how much money it has cost it becomes an even',
#  " any movie in recent memory . its a just great time if you do n't feel like taking yourself too seriously . xxmaj xxunk -"]

# %%
T = model.autoencoder.T.weight.detach().cpu().numpy()

# %%
def compute_k_closest_neighbors(vector,vectors,k=5):
    distances = np.sum((vectors - vector)**2,axis=1)
    distances = dict(zip(np.arange(len(distances)),distances))
    sorted_distances = sorted(distances, key = distances.get,reverse=True)
    output = sorted_distances[:k]
    
    return output

# %%
compute_k_closest_neighbors(vector,vectors)
# Out:
# [368, 2237, 5490, 8962, 8765]

# %%
vector = T[:,9]

df.iloc[compute_k_closest_neighbors(vector,vectors,k=10)].text.values
# Out:
# array(['menacing', 'blonde', 'whereas', 'na', 'brightly', 'when', 'vargas', 'todays', 'chewbacca', 'introduces'],
#       dtype=object)
